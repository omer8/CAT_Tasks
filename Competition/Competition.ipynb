# %% [markdown]
# # Classification Project
#
# #### This data set contains the following features:
# >- TransactionDT: - timedelta from a given reference datetime (not an actual timestamp)
# - TransactionAMT - transaction payment amount in USD
# - ProductCD - product code, the product for each transaction
# - card1 - card6 -payment card information, such as card type, card category, issue bank, country, etc
# - addr -adress
# - dist: -distance
# - P_ and (R__) emaildomain - purchaser and recipient email domain
# - C1-C14 -counting, such as how many addresses are found to be associated with the payment card, etc. The actual meaning is masked.
# - D1-D15 -timedelta, such as days between previous transaction, etc
# - M1-M9 -match, such as names on card and address, etc.
# - Vxxx -Vesta engineered rich features, including ranking, counting, and other entity relations.

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Gather Data

# %%
df = pd.read_csv(r'Downloads\Cat\train.csv')

# %%
test = pd.read_csv(r'Downloads\Cat\test.csv')

# %% [markdown]
# # Assess Data

# %%
df.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        3210227        0        5261726          59.000         W  17412
# 1        3397895        0       10374074          64.347         C   7949
# 2        3108818        0        2397517        1308.500         W   9500
# 3        3244037        0        6150927          57.950         W  10112
# 4        3385123        0       10025230          53.950         W   9500
#
#    card2  card3 card4  card5  ...        id_31  id_32  id_33  id_34  id_35  \
# 0  451.0  150.0  visa  226.0  ...          NaN    NaN    NaN    NaN    NaN
# 1  142.0  185.0  visa  226.0  ...  chrome 65.0    NaN    NaN    NaN      F
# 2  321.0  150.0  visa  226.0  ...          NaN    NaN    NaN    NaN    NaN
# 3  360.0  150.0  visa  166.0  ...          NaN    NaN    NaN    NaN    NaN
# 4  321.0  150.0  visa  226.0  ...          NaN    NaN    NaN    NaN    NaN
#
#   id_36 id_37  id_38  DeviceType  DeviceInfo
# 0   NaN   NaN    NaN         NaN         NaN
# 1     F     T      F     desktop     Windows
# 2   NaN   NaN    NaN         NaN         NaN
# 3   NaN   NaN    NaN         NaN         NaN
# 4   NaN   NaN    NaN         NaN         NaN
#
# [5 rows x 434 columns]

# %%
test.tail()
# Out:
#         TransactionID  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# 194874        3353774        9123849          49.000         W   6174  490.0
# 194875        3269455        6897318          44.107         C  15885  545.0
# 194876        3016750         754854          66.928         C   9633  296.0
# 194877        3255487        6491084          58.950         W   9500  321.0
# 194878        3200702        4981147         171.000         W  18103  288.0
#
#         card3 card4  card5  card6  ...                    id_31  id_32  id_33  \
# 194874  150.0  visa  226.0  debit  ...                      NaN    NaN    NaN
# 194875  185.0  visa  138.0  debit  ...  chrome 64.0 for android    NaN    NaN
# 194876  185.0  visa  138.0  debit  ...              chrome 62.0    NaN    NaN
# 194877  150.0  visa  226.0  debit  ...                      NaN    NaN    NaN
# 194878  150.0  visa  226.0  debit  ...                      NaN    NaN    NaN
#
#         id_34 id_35 id_36  id_37  id_38  DeviceType             DeviceInfo
# 194874    NaN   NaN   NaN    NaN    NaN         NaN                    NaN
# 194875    NaN     F     F      T      F      mobile  SM-G928V Build/MMB29K
# 194876    NaN     F     F      T      T     desktop                Windows
# 194877    NaN   NaN   NaN    NaN    NaN         NaN                    NaN
# 194878    NaN   NaN   NaN    NaN    NaN         NaN                    NaN
#
# [5 rows x 433 columns]

# %%
#shape
df.shape
# Out:
# (395661, 434)

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395661 entries, 0 to 395660
# Columns: 434 entries, TransactionID to DeviceInfo
# dtypes: float64(399), int64(4), object(31)
# memory usage: 1.3+ GB

# %%
def missing_value(df):
    mis_val = df.isnull().sum()
    mis_val_precent = (df.isnull().sum() / len(df))*100
    mis_val_table = pd.concat([mis_val,mis_val_precent],axis=1).rename(columns={0:'Missing Values', 1 : '% of Total Values'})
    return mis_val_table
nulls = missing_value(df)
nulls
# Out:
#                 Missing Values  % of Total Values
# TransactionID                0           0.000000
# isFraud                      0           0.000000
# TransactionDT                0           0.000000
# TransactionAmt               0           0.000000
# ProductCD                    0           0.000000
# card1                        0           0.000000
# card2                     6034           1.525043
# card3                     1055           0.266642
# card4                     1064           0.268917
# card5                     2874           0.726379
# card6                     1060           0.267906
# addr1                    44144          11.157026
# addr2                    44144          11.157026
# dist1                   236029          59.654351
# dist2                   370349          93.602604
# P_emaildomain            63030          15.930304
# R_emaildomain           303615          76.736145
# C1                           0           0.000000
# C2                           0           0.000000
# C3                           0           0.000000
# C4                           0           0.000000
# C5                           0           0.000000
# C6                           0           0.000000
# C7                           0           0.000000
# C8                           0           0.000000
# C9                           0           0.000000
# C10                          0           0.000000
# C11                          0           0.000000
# C12                          0           0.000000
# C13                          0           0.000000
# ...                        ...                ...
# id_11                   301182          76.121225
# id_12                   299007          75.571512
# id_13                   310327          78.432547
# id_14                   342092          86.460884
# id_15                   301180          76.120720
# id_16                   309009          78.099434
# id_17                   302267          76.395450
# id_18                   365475          92.370742
# id_19                   302305          76.405054
# id_20                   302332          76.411878
# id_21                   392159          99.114899
# id_22                   392155          99.113888
# id_23                   392155          99.113888
# id_24                   392433          99.184150
# id_25                   392181          99.120459
# id_26                   392159          99.114899
# id_27                   392155          99.113888
# id_28                   301182          76.121225
# id_29                   301182          76.121225
# id_30                   343759          86.882205
# id_31                   301651          76.239761
# id_32                   343745          86.878666
# id_33                   346608          87.602266
# id_34                   343583          86.837722
# id_35                   301180          76.120720
# id_36                   301180          76.120720
# id_37                   301180          76.120720
# id_38                   301180          76.120720
# DeviceType              301299          76.150796
# DeviceInfo              316173          79.910075
#
# [434 rows x 2 columns]

# %%
null = nulls[nulls['% of Total Values'] >= 25 ].index

# %%
df.drop(null,axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395661 entries, 0 to 395660
# Columns: 182 entries, TransactionID to V321
# dtypes: float64(174), int64(4), object(4)
# memory usage: 549.4+ MB

# %%
missing_value(df)
# Out:
#                 Missing Values  % of Total Values
# TransactionID                0           0.000000
# isFraud                      0           0.000000
# TransactionDT                0           0.000000
# TransactionAmt               0           0.000000
# ProductCD                    0           0.000000
# card1                        0           0.000000
# card2                     6034           1.525043
# card3                     1055           0.266642
# card4                     1064           0.268917
# card5                     2874           0.726379
# card6                     1060           0.267906
# addr1                    44144          11.157026
# addr2                    44144          11.157026
# P_emaildomain            63030          15.930304
# C1                           0           0.000000
# C2                           0           0.000000
# C3                           0           0.000000
# C4                           0           0.000000
# C5                           0           0.000000
# C6                           0           0.000000
# C7                           0           0.000000
# C8                           0           0.000000
# C9                           0           0.000000
# C10                          0           0.000000
# C11                          0           0.000000
# C12                          0           0.000000
# C13                          0           0.000000
# C14                          0           0.000000
# D1                         842           0.212808
# D10                      50865          12.855702
# ...                        ...                ...
# V292                         9           0.002275
# V293                         9           0.002275
# V294                         9           0.002275
# V295                         9           0.002275
# V296                       842           0.212808
# V297                         9           0.002275
# V298                         9           0.002275
# V299                         9           0.002275
# V300                       842           0.212808
# V301                       842           0.212808
# V302                         9           0.002275
# V303                         9           0.002275
# V304                         9           0.002275
# V305                         9           0.002275
# V306                         9           0.002275
# V307                         9           0.002275
# V308                         9           0.002275
# V309                         9           0.002275
# V310                         9           0.002275
# V311                         9           0.002275
# V312                         9           0.002275
# V313                       842           0.212808
# V314                       842           0.212808
# V315                       842           0.212808
# V316                         9           0.002275
# V317                         9           0.002275
# V318                         9           0.002275
# V319                         9           0.002275
# V320                         9           0.002275
# V321                         9           0.002275
#
# [182 rows x 2 columns]

# %%
df['isFraud'].value_counts(normalize=True)
# Out:
# 0    0.965331
# 1    0.034669
# Name: isFraud, dtype: float64

# %%
for col in df.columns:
    if df[col].dtype == 'float':
        df[col].fillna(df[col].mean(),inplace=True)
    elif df[col].dtype == 'int':
        df[col].fillna(df[col].mode().values[0],inplace=True)
    else:
        df[col].fillna(df[col].mode().values[0],inplace=True)

# %%
missing_value(df)
# Out:
#                 Missing Values  % of Total Values
# TransactionID                0                0.0
# isFraud                      0                0.0
# TransactionDT                0                0.0
# TransactionAmt               0                0.0
# ProductCD                    0                0.0
# card1                        0                0.0
# card2                        0                0.0
# card3                        0                0.0
# card4                        0                0.0
# card5                        0                0.0
# card6                        0                0.0
# addr1                        0                0.0
# addr2                        0                0.0
# P_emaildomain                0                0.0
# C1                           0                0.0
# C2                           0                0.0
# C3                           0                0.0
# C4                           0                0.0
# C5                           0                0.0
# C6                           0                0.0
# C7                           0                0.0
# C8                           0                0.0
# C9                           0                0.0
# C10                          0                0.0
# C11                          0                0.0
# C12                          0                0.0
# C13                          0                0.0
# C14                          0                0.0
# D1                           0                0.0
# D10                          0                0.0
# ...                        ...                ...
# V292                         0                0.0
# V293                         0                0.0
# V294                         0                0.0
# V295                         0                0.0
# V296                         0                0.0
# V297                         0                0.0
# V298                         0                0.0
# V299                         0                0.0
# V300                         0                0.0
# V301                         0                0.0
# V302                         0                0.0
# V303                         0                0.0
# V304                         0                0.0
# V305                         0                0.0
# V306                         0                0.0
# V307                         0                0.0
# V308                         0                0.0
# V309                         0                0.0
# V310                         0                0.0
# V311                         0                0.0
# V312                         0                0.0
# V313                         0                0.0
# V314                         0                0.0
# V315                         0                0.0
# V316                         0                0.0
# V317                         0                0.0
# V318                         0                0.0
# V319                         0                0.0
# V320                         0                0.0
# V321                         0                0.0
#
# [182 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        print(col)
# Out:
# ProductCD
# card4
# card6
# P_emaildomain

# %%
df['P_emaildomain'].nunique()
# Out:
# 59

# %%
df.drop(['P_emaildomain','TransactionID'],axis=1,inplace=True)

# %%
df['ProductCD'] = df['ProductCD'].astype('category').cat.codes
df['card4'] = df['card4'].astype('category').cat.codes
df['card6'] = df['card6'].astype('category').cat.codes

# %%
df.sample(10)
# Out:
#         isFraud  TransactionDT  TransactionAmt  ProductCD  card1  card2  \
# 337604        0       15533714          28.896          0  16136  204.0
# 153920        0       15556919          57.950          4  15986  360.0
# 163949        0       12514094         130.500          4  17363  111.0
# 339555        0         245762          25.000          4   6951  111.0
# 301803        0        9898006          59.000          4  12065  575.0
# 207334        0       11378361         149.950          4   6530  206.0
# 14832         0        1744075          65.950          4  12577  268.0
# 174096        0       13102181           2.292          0  15885  545.0
# 254949        0       15187361        1849.070          4  15497  490.0
# 104253        0         585450         170.000          4   7069  111.0
#
#         card3  card4  card5  card6  ...   V312  V313        V314  V315  \
# 337604  185.0      3  138.0      2  ...    0.0   0.0    0.000000   0.0
# 153920  150.0      2  229.0      2  ...    0.0   0.0    0.000000   0.0
# 163949  150.0      3  226.0      2  ...  549.0   0.0    0.000000   0.0
# 339555  150.0      3  226.0      2  ...   25.0   0.0    0.000000   0.0
# 301803  150.0      2  224.0      2  ...    0.0   0.0   59.000000   0.0
# 207334  150.0      2  126.0      2  ...    0.0   0.0  460.850006   0.0
# 14832   150.0      3  166.0      2  ...    0.0   0.0    0.000000   0.0
# 174096  185.0      3  138.0      2  ...    0.0   0.0    0.000000   0.0
# 254949  150.0      3  226.0      2  ...    0.0   0.0    0.000000   0.0
# 104253  150.0      2  202.0      2  ...  220.0  87.0  730.000000  87.0
#
#               V316         V317        V318        V319        V320  \
# 337604    0.000000     0.000000    0.000000    0.000000    0.000000
# 153920    0.000000     0.000000    0.000000    0.000000    0.000000
# 163949  323.850006  1007.849976  323.850006    0.000000    0.000000
# 339555    0.000000     0.000000    0.000000    0.000000    0.000000
# 301803    0.000000     0.000000    0.000000    0.000000    0.000000
# 207334    0.000000     0.000000    0.000000    0.000000    0.000000
# 14832     0.000000     0.000000    0.000000  140.899994  140.899994
# 174096    0.000000     0.000000    0.000000    0.000000    0.000000
# 254949    0.000000     0.000000    0.000000    0.000000    0.000000
# 104253    0.000000     0.000000    0.000000    0.000000    0.000000
#
#               V321
# 337604    0.000000
# 153920    0.000000
# 163949    0.000000
# 339555    0.000000
# 301803    0.000000
# 207334    0.000000
# 14832   140.899994
# 174096    0.000000
# 254949    0.000000
# 104253    0.000000
#
# [10 rows x 180 columns]

# %%
X = df.drop('isFraud',axis=1)
y = df['isFraud']

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)

# %%
feat_importances
# Out:
# TransactionDT     0.064280
# TransactionAmt    0.057472
# card1             0.037542
# C1                0.037042
# card2             0.035020
# addr1             0.031255
# C2                0.027874
# C14               0.026362
# C13               0.024021
# C11               0.020916
# card5             0.019530
# C6                0.017778
# card6             0.013163
# C12               0.012949
# V86               0.012772
# card4             0.012681
# D15               0.012526
# V87               0.012383
# D1                0.011658
# ProductCD         0.011146
# C4                0.011124
# C8                0.010875
# C10               0.009856
# V78               0.008640
# card3             0.008465
# V307              0.008316
# D10               0.007987
# V94               0.007749
# V283              0.007349
# C9                0.007072
#                     ...
# V63               0.001281
# V90               0.001267
# V59               0.001244
# V60               0.001237
# V297              0.001184
# V31               0.000956
# V117              0.000778
# V28               0.000764
# V22               0.000688
# V57               0.000659
# V114              0.000649
# V113              0.000593
# V111              0.000557
# V110              0.000546
# V32               0.000464
# V15               0.000460
# V121              0.000412
# V119              0.000399
# V65               0.000363
# V122              0.000350
# V14               0.000345
# V16               0.000308
# V89               0.000298
# C3                0.000290
# V118              0.000283
# V88               0.000266
# V120              0.000176
# V107              0.000120
# V27               0.000108
# V305              0.000007
# Length: 179, dtype: float64

# %%
X = X[feat_importances[:20].index]

# %%
X.sample(8)
# Out:
#         TransactionDT  TransactionAmt  card1     C1       card2  addr1     C2  \
# 355619        2057203          554.00   2455    1.0  321.000000  204.0    2.0
# 61344         8106972           75.00  12758    1.0  161.000000  181.0    1.0
# 248185        7599285           24.00   7585    1.0  553.000000  315.0    3.0
# 175863        2099108          226.00   2616    3.0  362.663447  264.0    1.0
# 183200        1828261           20.95   9995  110.0  479.000000  143.0  105.0
# 108320        2079402          125.00   2803    1.0  100.000000  433.0    1.0
# 5116          8627614           39.00   3762    1.0  555.000000  325.0    1.0
# 15374        12536134          159.95  15185    2.0  332.000000  264.0    2.0
#
#          C14    C13   C11  card5    C6  card6  C12       V86  card4  \
# 355619   1.0    1.0   1.0  226.0   2.0      1  0.0  1.000000      3
# 61344    1.0    2.0   1.0  195.0   1.0      2  0.0  1.065119      2
# 248185   1.0   40.0   1.0  226.0   1.0      1  1.0  1.000000      3
# 175863   3.0    4.0   1.0  102.0   1.0      1  0.0  1.000000      1
# 183200  92.0  413.0  83.0  166.0  88.0      2  0.0  1.000000      3
# 108320   1.0    1.0   1.0  226.0   1.0      2  0.0  1.065119      3
# 5116     1.0    2.0   1.0  226.0   1.0      2  0.0  1.000000      3
# 15374    2.0   11.0   1.0  226.0   1.0      2  0.0  1.000000      3
#
#                D15       V87     D1  ProductCD
# 355619    3.000000  1.000000    3.0          4
# 61344   163.501085  1.099194   77.0          2
# 248185  557.000000  1.000000  556.0          4
# 175863  111.000000  1.000000    0.0          4
# 183200  466.000000  1.000000  163.0          4
# 108320  163.501085  1.099194    0.0          2
# 5116     17.000000  1.000000   17.0          4
# 15374   509.000000  1.000000   35.0          4

# %% [markdown]
# ## Split data into training set and test set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42,stratify = y)

# %% [markdown]
# ## Try Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
param_grid = [{'n_estimators': [10,100,500,1000], 'max_features': [10,30,50]}]
grid = GridSearchCV(rfor,param_grid,scoring='roc_auc',cv=5,return_train_score=True)

# %%
rfor = RandomForestClassifier(n_estimators=500)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(rfor,X_train, y_train, cv=3,scoring="roc_auc")
# Out:
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
scores
# Out:
# array([0.88959903, 0.89089224, 0.89221707])

# %%
rfor.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_for = rfor.predict(X_test)

# %%
roc_auc_score(y_test,y_for)
# Out:
# 0.791100116721883

# %%
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score

# %%
print(classification_report(y_test,y_pred))
print('**********************************')
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     38195
#            1       0.92      0.47      0.62      1372
#
#     accuracy                           0.98     39567
#    macro avg       0.95      0.73      0.80     39567
# weighted avg       0.98      0.98      0.98     39567
#
# **********************************
# [[38141    54]
#  [  734   638]]

# %%
roc_auc_score(y_test,y_pred)
# Out:
# 0.7318003898209929

# %% [markdown]
# ## Try Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import GridSearchCV
# Create lists of parameter for Decision Tree Classifier
criterion = ['gini', 'entropy']
max_depth = [4,6,8,12]

    # Create a dictionary of all the parameter options 
    # Note has you can access the parameters of steps of a pipeline by using '__’
parameters = dict(criterion=criterion,
                      max_depth=max_depth)

    # Conduct Parameter Optmization With Pipeline
    # Create a grid search object
clf = GridSearchCV(tree, parameters)

    # Fit the grid search
clf.fit(X_train, y_train)
# Out:
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort=False, random_state=None,
#                                               splitter='best'),
#              iid='warn', n_jobs=None,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 6, 8, 12]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
tree = DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=320,
                       max_features=18, max_leaf_nodes=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, presort=False,
                       random_state=None, splitter='best')

# %%
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=320,
#                        max_features=18, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
tree_pred = tree.predict(X_test)

# %%
roc_auc_score(y_test,tree_pred)
# Out:
# 0.8065737043886267

# %%
y_new = tree.predict(test)

# %%
clf.best_estimator_
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=12,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %% [markdown]
# ## Try Resampling the data

# %%
from sklearn.utils import resample

# %%
x = pd.concat([X_train,y_train],axis = 1)

# %%
fraud = x[x.isFraud == 1]
not_fraud = x[x.isFraud == 0]

# %%
fraud_upsampled = resample(fraud,
                          replace=True, # sample with replacement
                          n_samples=len(not_fraud), # match number in majority class
                          random_state=27) # reproducible results

# combine majority and upsampled minority
upsampled = pd.concat([not_fraud, fraud_upsampled])

# %%
upsampled.isFraud.value_counts()
# Out:
# 1    343749
# 0    343749
# Name: isFraud, dtype: int64

# %%
X=upsampled.drop('isFraud',axis=1)
y=upsampled['isFraud']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42,stratify = y)

# %% [markdown]
# ## Try Logistic Regression model after resampling the data

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()

# %%
log.fit(X_train,y_train)

# %%
y_pred2 = log.predict(X_test)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_pred2)
# Out:
# 0.6467636363636364

# %%
from sklearn.model_selection import GridSearchCV

# %%
logreg = LogisticRegression(class_weight='balanced')
param = {'C':[0.001,0.003,0.005,0.01,0.03,0.05,0.1,0.3,0.5,1,2,3,3,4,5,10,20]}
clf = GridSearchCV(logreg,param,scoring='roc_auc',refit=True,cv=10)
clf.fit(X_train,y_train)
print('Best roc_auc: {:.4}, with best C: {}'.format(clf.best_score_, clf.best_params_))
# Out:
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\omar mohamed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users
for col in test.columns:
    if test[col].dtype == 'object':
        print(col)
# Out:
# ProductCD
# card4
# card6
# P_emaildomain

# %%
test.drop(['P_emaildomain','TransactionID'],axis=1,inplace=True)

# %%
test['ProductCD'] = test['ProductCD'].astype('category').cat.codes
test['card4'] = test['card4'].astype('category').cat.codes
test['card6'] = test['card6'].astype('category').cat.codes

# %%
test = test[feat_importances[:20].index]

# %%
test
# Out:
#         TransactionDT  TransactionAmt  card1     C1  card2       addr1     C2  \
# 0            12153579         724.000   7826    3.0  481.0  387.000000    1.0
# 1            15005886         108.500  12544    2.0  321.0  476.000000    1.0
# 2             6970178          47.950   9400    1.0  111.0  315.000000    1.0
# 3             5673658         100.599  15885    2.0  545.0  290.349683    3.0
# 4             6886780         107.950  15497   10.0  490.0  299.000000   14.0
# 5            10444930         280.000   7919    6.0  194.0  472.000000    4.0
# 6            10442147         311.950   9002  106.0  453.0  315.000000  105.0
# 7            12254683         330.990  14183    2.0  555.0  184.000000    1.0
# 8             9228284          10.392   9633    4.0  130.0  290.349683    5.0
# 9              739585         335.000  11207    2.0  361.0  231.000000    2.0
# 10            9409651          57.000   9500    2.0  321.0  204.000000    4.0
# 11            1649422         108.950  17188    2.0  321.0  299.000000    1.0
# 12            3436459         222.000  15066    6.0  170.0  325.000000    1.0
# 13           11835503         209.950   1804    1.0  161.0  123.000000    1.0
# 14            6650153         270.000  18249    1.0  360.0  205.000000    1.0
# 15            1873107         100.000  17188    2.0  321.0  299.000000    2.0
# 16            4656646         107.950   7919    1.0  194.0  264.000000    1.0
# 17            4801943         439.990   6341    1.0  555.0  203.000000    1.0
# 18           14860149          47.950   7638   10.0  174.0  315.000000   10.0
# 19           14186414          58.950  16132    3.0  111.0  299.000000    1.0
# 20            8012474        1090.190  18238    1.0  361.0  472.000000    1.0
# 21            9207941         209.950  11233    5.0  321.0  272.000000    3.0
# 22           14941360          47.000   3651    2.0  360.0  272.000000    1.0
# 23           11153036          57.950  10057  144.0  225.0  327.000000  129.0
# 24            9409267          49.000   2455    2.0  321.0  469.000000    1.0
# 25            7888182          58.950  18366    1.0  111.0  220.000000    1.0
# 26           10356189          10.876  15885    1.0  545.0  290.349683    2.0
# 27             160627         226.000   6481    1.0  111.0  204.000000    1.0
# 28            9422351          32.990   9300    1.0  103.0  290.349683    1.0
# 29             517872          42.000   3574  110.0  232.0  264.000000   85.0
# ...               ...             ...    ...    ...    ...         ...    ...
# 194849        2171716         100.000  10486    1.0  514.0  494.000000    1.0
# 194850        7918592          29.000   6816    3.0  464.0  264.000000    1.0
# 194851        1574392         100.000  15063    1.0  514.0  299.000000    1.0
# 194852        9992489         107.950  10616    1.0  583.0  181.000000    1.0
# 194853        2647930          50.000  14454    1.0  208.0  315.000000    1.0
# 194854       11652289          34.000  10112    1.0  360.0  299.000000    3.0
# 194855        9995648          67.950   8586    2.0  555.0  420.000000    4.0
# 194856        3949552          77.000  10023    1.0  111.0  315.000000    2.0
